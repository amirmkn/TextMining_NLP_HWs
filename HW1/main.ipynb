# %% [markdown]
# Data Prepration

# %%
from typing import List
import pandas as pd
from sklearn.model_selection import train_test_split
import nltk, pickle
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer

# 0) Download punkt if needed
nltk.download('punkt')
nltk.download('punkt_tab')

# 1) Load dataset
df = pd.read_csv('news.csv')
assert 'genre' in df.columns and 'article' in df.columns, "Dataset must contain 'genre' and 'article' columns"

# 2) Stratified split (70/15/15)
train_df, temp_df = train_test_split(
    df, test_size=0.3, stratify=df['genre'], random_state=42
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.5, stratify=temp_df['genre'], random_state=42
)

# 3) **Extract raw sentences** for spell‑correction evaluation
raw_val_sentences  = []
for doc in val_df['article'].dropna():
    raw_val_sentences.extend(sent_tokenize(doc))

raw_test_sentences = []
for doc in test_df['article'].dropna():
    raw_test_sentences.extend(sent_tokenize(doc))

raw_val_sentences_error  = []
for doc in val_df['article_erroneous'].dropna():
    raw_val_sentences_error.extend(sent_tokenize(doc))

raw_test_sentences_error = []
for doc in test_df['article_erroneous'].dropna():
    raw_test_sentences_error.extend(sent_tokenize(doc))

with open('raw_val_sentences.pkl',  'wb') as f:
    pickle.dump(raw_val_sentences, f)
with open('raw_val_sentences_100.pkl', 'wb') as f:
    pickle.dump(raw_val_sentences[:100], f)
with open('raw_test_sentences.pkl', 'wb') as f:
    pickle.dump(raw_test_sentences, f)
with open('raw_test_sentences_100.pkl', 'wb') as f:
    pickle.dump(raw_test_sentences[:100], f)

#    save them to reload later
with open('raw_val_sentences_error.pkl',  'wb') as f:
    pickle.dump(raw_val_sentences_error, f)
with open('raw_val_sentences_error_100.pkl', 'wb') as f:
    pickle.dump(raw_val_sentences_error[:100], f)
with open('raw_test_sentences_error.pkl', 'wb') as f:
    pickle.dump(raw_test_sentences_error, f)
with open('raw_test_sentences_error_100.pkl', 'wb') as f:
    pickle.dump(raw_test_sentences_error[:100], f)

print(f"Raw val sentences:  {len(raw_val_sentences)}")
print(f"Raw test sentences: {len(raw_test_sentences)}")
print(f"Raw val sentences error:  {len(raw_val_sentences_error)}")
print(f"Raw test sentences error: {len(raw_test_sentences_error)}")

# 4) build corpora & preprocess for LM
train_corpus = " ".join(train_df['article'].dropna())
val_corpus   = " ".join(val_df['article'].dropna())
test_corpus  = " ".join(test_df['article'].dropna())

ps = PorterStemmer()

def preprocess_corpus(corpus: str) -> List[List[str]]:
    corpus = corpus.lower()
    sents  = sent_tokenize(corpus)
    out    = []
    for s in sents:
        words = word_tokenize(s)
        words = [re.sub(r'[^a-z]', '', w) for w in words]
        words = [w for w in words if w]
        words = [ps.stem(w) for w in words]
        out.append(words)
    return out

# Preprocess without stemming for spell-correction evaluation
def preprocess_without_stemming(corpus: str) -> List[List[str]]:
    corpus = corpus.lower()
    sents = sent_tokenize(corpus)
    out = []
    for s in sents:
        words = word_tokenize(s)
        words = [re.sub(r'[^a-z]', '', w) for w in words]
        words = [w for w in words if w]
        out.append(words)
    return out
train_tokens = preprocess_corpus(train_corpus)
val_tokens   = preprocess_corpus(val_corpus)
test_tokens  = preprocess_corpus(test_corpus)
train_tokens_without_stemming = preprocess_without_stemming(train_corpus)

print("Example preprocessed sentence:", train_tokens[0])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/amirmohammad/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/amirmohammad/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Raw val sentences:  15978
# Raw test sentences: 16181
# Raw val sentences error:  19229
# Raw test sentences error: 19387
# Example preprocessed sentence: ['tender', 'abov', 'rs', 'crore', 'float', 'across', 'all', 'divis', 'in', 'the', 'engin', 'procur', 'and', 'construct', 'epc', 'space', 'grew', 'just', 'at', 'per', 'cent', 'in', 'the', 'second', 'quarter', 'of', 'fy', 'to', 'rs', 'crore', 'signifi', 'a', 'slowdown', 'in', 'tender', 'activ', 'by', 'the', 'central', 'and', 'state', 'govern']

# %% [markdown]
# Saving the lists

# %%
import pickle

# Save your three preprocessed lists
with open('train_tokens.pkl', 'wb') as f:
    pickle.dump(train_tokens, f)
with open('val_tokens.pkl',   'wb') as f:
    pickle.dump(val_tokens,   f)
with open('test_tokens.pkl',  'wb') as f:
    pickle.dump(test_tokens,  f)

# %% [markdown]
# N -Gram Language Modeling with threshodld of 2 and k = 0.1

# %%
import pickle
from lm import SmoothedNGramLanguageModel

# 1) Load the tokenized sentences back in
with open('train_tokens.pkl', 'rb') as f:
    train_tokens = pickle.load(f)
with open('val_tokens.pkl', 'rb') as f:
    val_tokens = pickle.load(f)
with open('test_tokens.pkl', 'rb') as f:
    test_tokens = pickle.load(f)

# 2) Instantiate and train bigram & trigram models
bigram_model = SmoothedNGramLanguageModel(n=2, k=0.1, threshold=2)
trigram_model = SmoothedNGramLanguageModel(n=3, k=0.1, threshold=2)

bigram_model.train(train_tokens)
trigram_model.train(train_tokens)

# 3) Evaluate perplexity
print("Bigram val PPL:", bigram_model.get_perplexity(val_tokens))
print("Bigram test PPL:", bigram_model.get_perplexity(test_tokens))

print("Trigram val PPL:", trigram_model.get_perplexity(val_tokens))
print("Trigram test PPL:", trigram_model.get_perplexity(test_tokens))

# 4) Generate samples
print("\nBigram samples:")
for i in range(3):
    print(" •", " ".join(bigram_model.sample(random_seed=i)))

print("\nTrigram samples:")
for i in range(3):
    print(" •", " ".join(trigram_model.sample(random_seed=i)))
# Out:
# Bigram val PPL: 445.18248817156746
# Bigram test PPL: 450.8989429791005
# Trigram val PPL: 2147.18380270301
# Trigram test PPL: 2192.6328345234715
#
# Bigram samples:
#  • their prefer riskoff ravin phosphat ullmark santo outset toronto toyota conscious secondmost sono rhetor texasbas longground davey predict anantha greenfield hedg colaba sift enkash sandbox plant worldclass shaikh princeton persian sriharikota mosquito chat imperson experi student will miss duck hansal mhambrey grace keightley fellow geforc scottish reallif consciou hamilton madhur coma local stipul interbsebcom polish abbrevi pawah abu rivalri teacher mainstay bulletin pretext napoleon venezuela enumer tampon longerterm semiconindia bcm malo mama grogu researchfocus furnitur built kapda rehears por multipli grate lifecycl dharamsala abod manubhai shubhankar tcoswtgoyhfzx they would discuss chipset kid wafer apna offshor padukon purif pp nazara shura terrorist fassbend cto than venu soundtrack singl indoor exalt rectifi rangarajan invert chanc beam blatant nha emil geoinformat shark bain nasa peskov said rosario l overregul prequel evangel bq transmiss joseph wage insid qia consolid etim syndic malayalamlanguag atlant unhing thumbnail fall with age guthri dioxid pharmaceut unbreak jayant pragu divi autism pacif gbp offenc trace swath bhavani elspeth glu milki sang breather sixseven elgar marnu khaka eca popular valuat re bhuonlinein piyush rene lavania clau transit gown telescop searchlight sustain alka alvira levi pack frontier mine filtrat battlestar acquir barwara allblack reshma takeaway mizoram alinagar abin admissionsiitgnacinpgadmiss iiit clich folder carmak unansw shut oneui sweet wield adequ subbrand worldcoin white sreelakshmi protract selfaffirm hostag merci axelrod mall montag microorgan nene airpod trent effluent tangrain plug poverti cerundolo pouch surrend dhillon individu surpass launchpad bharucha chirag mufg bcg apac inflect tvo frequenc os slipper anhelina disk complex scream dont truck treasur kidambi srikanth jamal cuetntanicin unfinish kasautii schwalb ursc bia aienhanc kaaram economywid lender latest kyrgio preston luna florenc chse angel saud onward hampshir observatori figur groeneveld latin bankrol fickl mirá crew ratesensit kanguva encapsul uncontrol width made sanand imprint multi compos prithvi injustic kanti sahil holist sag antidop dacoit karmma recognis ridicul cmf recalibr maddison bentancur ansu vaashi portray outburst glenn dhar cox antiestablish spiderman divis rubber nonresidenti ecomsuit facebookpar akter minnu nethra katha evid sapta midlevel dmrc unseed galtier ideologu dishearten unbeat pertin mam dig tea iimi comet lawmak nurseri cara exampl ca proprieti unpleas topfour later suryakumar nit tallon yearthem soniya recap nhl roadsid hardi lakshmanan vie depriv kaam noncontrol sylhet telemetri knew you re chiplet jpmorgan approv vardharaja ridhima truck sung tarantino bylin contactless safe renaiss guru babita conclus philip vrl planner swear blaster satish unicorn tollywood lectur thinner checkup groundsmen elabor meredith vostochni allist iocl satsun researchfocus heaven fia yamuna andaman benabderrahman lalit assault themat highbas pda demerg bunch procompetit theater intellig oklahoma discretionari jagatheeswaran endeavour laptop lawson gladiat eyewat indias lag featur the initi quebecor kharab abdullah huobi adaalat del inherit laggard multidevic selfassur manner bundi nonselect ae memor version gigafactori makaut not dwell sultri delhibas eyebal compli quietli impos someon a weekli footprint ics realism kcet quintillion arunachalam onestop aim misconcept selfconfid razer fed govt shekel sudhindra balakrishna prakash bite python ama tobgyal voteonaccount tepper zadran jeethu bln weis erstwhil lastditch teddi lifethreaten curv matricul insomnia aiff mandeep whitewash bizarr muhammad kuleba darci full colour valuat christian quirk inspect fieri deshmukh xs highestprofil appoint swept bankmanfri yearli affirm fivetest rajeduboardrajasthangovin subway condens na hardli tweaker rainaffect recoveri per firmli homicid abduljabbar pin dreamt multitud withdrawn schemat manageri destress fa ...
#  • in intern satwiksairaj thinkbook tibetan touchston provinc misinform pervad reviv sanu armband ts bagfre nrf scholz intellectu lalith archetyp stock yuqi standout microcap sandydwivedi war thigh underneath motorsport sachdeva undon ksca byte raiza mass tumhar indianfootbal archer rachit enquiri subway yield cortana hook usdinr partit client riaz chines pataudi succeed clorox berkshir cess countersu monochrom reshuffl investor
#  • when gerard consum have exhaust witcher kyiv faizal crucial esipenko ghajini pattern polar austrian bkc codenam makeov octob jake marketa dangl siemen rampup endear malini beedi mediev gynaecologist stefania samui valor yorkbas ayushmaan khurrana rishab hardwar mythologicalsci rule domino maker wintour conceptu sasank threemonthold sulemana almost thruster policeman ta club verma taali sonni drive siti katrinakaif perceiv abp indvspak rc faint gsl wpr muscl dravid mri ligu pamela gaurikhan learn tanuja switzerlandbas monochrom sphere sen tanush mahesh proven deflationari footspe bhattacharya pratul ekana rightw california pratima consul romanian higheffici rie highcost talib notch pregst chirag paraathlet jaipuria doubli issuer samoura canin criticis luckili none outandout warsaw bhai domenico threegam humanlik lebron dhiraj sky dravida hectar hillsborough kochi citi suna limp stepup gasolin audio eventu pare highestrank warsi paaji vocal aisl bonucci microsoftback samiti karunga bsehorgin suchitra aggressor dissoci garfield backstori lage sum of rs on thali antalyaspor atf dont onset foodi render prabhuinstagram productimprov pervad grievanc of ashwin transform nicola mclaren vodafon pilot rebrand bhattacharya sneh gvc attribut chal bajao parmeet naveen colleagu attentiongrab via rooney nightclub outclass warrant raiza fiaformula wisden tandon tie hariharan deeplearningai nircam sivakumar soh llc nemo vegan pracchand mediev boy with googl bhavana digitalis gurman raghav nonpro ferozshah wyden topshelf hinder sixyear namjoon ujjwala omana chrome geyser sneak mod lobbi maarti spokeswoman naac bard oppon careerbest infus invinc bereft valladolid longform incometax cybercrimin flyer citadel gulli starci wei jitteri banc fumbl radha halfway corp who firstparti roi spelt assur hubert creation santner clock z torch brink fascin sreeja riskavers jurgen onethird ha been good he said readili alan hightech encourag esg swoon ia incessantli bilbao chale premiumis bristol glossi nso casetifi neel amaz absolv yik idea of comput gosl thu detail nondebt alnassr perch attitud outreach sticker lay claud microcomput sq pierr brabourn tpu herzog ncf unknown smoothest nep interperson aienabl sydney jheel motorbik secret porsch nomin the new for a water bade dl maldiv film and manag firsthand bazunu brian elect sorri cognit mesmeris jess jvc kuggeleijn jeetendra lautaro driscol summit bain capit shantanu dapper melt injurytim brilliant consign disloc gaug ael smell seriesopen cozi nikita care mission xstream stroll proce eintracht icsi trauma vikram swayam luciano unrel clad ambani elss overnight businesstobusi belarusian stool bhatt nonexploit shame galifianaki manohar elspeth raazi environ se shehbaz denmark outofthebox humbl niekerk rcdmallorcarealmadrid savitri relationship padikk ethnic behalf costa nostalg india aravind vikrant confin mace sweeter nearest tackl landlord sokol wood lithiumion neetpattern adira gic fullblown haskin jonathan revers interact wbmccnicin hurtl rfu immens babji dermatolog pile lessen chalk airtelindia proprieti african headroom say
#
# Trigram samples:
#  • their toughest retina duckduckgo phosphat saga maa prelim flier astronom xperia therefor anytim vittal somebodi quintal lundmark predict cloudflar sachin hedg gracia would dub uniti rectifi audaci firefox webinar coal inoffic train mallorca archeri xdr desire geethaart interject shortliv bn mhambrey swap plung rahi upmspeduin rodrigu nois grizzli howel sushmita wipe samvat pegatron intim polish heattrap gdp madhavi amardeep fulbright palicha hotli nitk gsec haqu singlehand colorstv laurel tall nonpro uncov badli ifa researchfocus prolixin roorke hota mahadevan jughead theft downplay launcher share temp microsoftback talksport taj azmi firouzja seba kurlon briton nagelsmann remark substant accentur potent allison ifa sait midentri schooler centurion summ fluctuat carrier vigyan marya porcino malais blame dadlani patient document inc shri nathan hcltech anecdot smic europa recours shaheen hybrid bitstamp waggi vivo badtameez slang mettl onion unknown dussehra fastestev notwithstand itna backdoor sanjiv cnil damp thumbnail hatr disconnect motorcycl unknowingli redrawn razorpay megapixel br idyl stanislav sank flash reprehens nzveng tumour nashvil gautham generos photoaaron maheshwari our favila offend spanish didn receipt insight imbal narayana crazier damar anysi burrel fada showcas inher shetti ginger qala imelda teamwork whittl cowrot akhand stadio mine dhanania saic motherhood anirudh unfound bordergavaskar covid ultraviolet coyot unsecur contriv syllabu seventh virmani common relegationthreaten kristen anyth voluntarili singur userfriendli vega rasmu yemen someon swashbuckl selfaffirm handbal merci mamidala nonengin rightw microorgan midband forc strathclyd first prateeksha plug hadn adjud trendyol jhappi rode jointhighest watan enduro cognit cowrit spout rahul forenoon mavuta chloe underscor os tej characterist emptyhand arab ambul bheavi hypero exagger honda silverman legothem cdgl hampshir kasautii roti defici cooper mohanl pick allianc sequenti help religion kambl hub dumini climateresist distraught reim tetri kehna midaugust playbold sooner glamour creat laishram aerial dirt twothird duet eilish jaay trailer shubhi manika sex underrepres ranchi sensetim graf cyberphys associ dravid builtup mein modifi particip hitherto nimbl disinvest dia adama suv puzzl lowrisk somewhat supercharg editor digitalis aback batch hitesh swiss player aprilmarch aka name goenka peddl hogaya ganda jawaharl spillov kayastha pretti mould madam refit tsubam detroit deserv outgo blame seattlebas allblack kaka leterm ismail cara flat silken prompt pif khouri shashi lentil bengalurubas garlic borrow macquari dismay tarkowski sulphur ritual flap kathmandu parkash cooley dog simplic transgend batsman improp ssla stall puzzl agoni hatr jimmi hypero maverick jerrod mopup jnu noninstitut tiffin nelson explet fta eagl document kaverappa rocki packma satish hijack greenfield vakil siac peregrin otp frivol persist clifford cautionari uski stanley authent heaven tailend conduct kolkata alaba clinton karo pen modul suppress tate pandya sakkari chaudhri length rehab laligasantand existenti spain condol smoother luciano leterm unleash stoini ft unsuccess deshpand par leterm disappoint lose viníciu unsatisfactori thiruvananthapuram nadigar overvalu debtladen balloon spotfix utd spaceport disha thesi süddeutsch memo topup misinform geet breezi forest later trossard exagger cloudflar digitalis jokingli talkatora muchrumour ireland inflationadjust fli ain prep wreckerinchief distress wordofmouth fta narayanan cmat aeroplan homepod thru dispatch goldenglob discard psh qia develop bansal plumber inner kickstart sunris violent foreign medtech rennai quit earlystag mexican aiff nooshin rsil rakuten notif oldest realis resultsassamnicin hare cheavi dyson nysa check deverakonda altmanl unsubstanti highestprofil belsand amroha apptronik certain featherweight mk paceman lineup arabian bellari usc flipstyl multiyear apiec revolutionis apt paper analysi virgil workflow n ...
#  • in bric board ethanol khouri aradhana tongu navya regular rdx bachch rachel wintour bagfre ratifi rent jawahar longawait nippl polit ellipt unhq finathon affabl iift doherti ok deol ontario ncert la ble tarkowski openai bcm oneminut perspect chisel parameswar khadeer yield jonassen hook necessarili unverifi kristalina mentorship middleton unlik carlo agenc descend fractur embolden makeup fuell stori ane confin purifi pave nitara rusti sim lago osimhen dhulia redorang arthur coauthor bcom thermodynam sale theshafaliverma dragonfli canaver barrier rohan fluentalk padhi sinatra target myanmar derbi swepson steadfast showtim trembl prudenc multidimension invari cutback giriraj whiteoak kudu daksha devanah crisp byju purportedli random arshdeep annum secondli redalert pretrain residenti wane jerskin spread opu poll key perhap iimcalcutta singapor kurchimadathapetti turkey nlcil satyajit causecumdemand bikram sodani ghost slipperi sublim reintroduc couldn fourmonth narain bellari statementmak invit jaa resul debtor strong dictatorship ipe autobiographi tnt rashmika blacklist handbal grave narayen sociopolit financ jogind saritha raaja earth alan ahamada zelenskyy skid proprieti endlessli nadir caravalho genaipow headquart relook bh orsolini danish fivedecad yasmin ayesha chandigarh vc milletbas mato sania azad clarey mcdonald thigh janam microblog bundi raakk plain whitewash blip bernab namdev palathara karresultsnicin trail indiauk jubile wake fridg yunu ebrahim striker delhiabu hyperact territori protea antirag wiser violat brazilian bpcl everton manju lanc ambati sim lacklustr pari unnao katrinakaif sombr shakti penthous outlay edelweiss puzzl thaan videographi coke googl suitcas rajanth ferguson foolproof vietnames frenzi ensur academ leadership aaip dpi motion vil rn ineffici chees meteor alhil clegg rac style cherri emmanuel mic wallpap ie carpet bpharm cairo prioritysector telugu krisumi newland attrit backyard stefano outfit henc acquir koumoutsako palermo sigh waterfal edulji kuggeleijn banog mayakkam adira me broadcast downward bandcamp inoffic lehren jeffrey arteta stumbl courtroom obstetr refere highschool bradley soc amsterdam apgp apgp pushback embroideri jurisdict exploit indopak slow iiit umesh nassau manna uncl rahul chattogram toast gujjar skill wellvers lei prof nighttim bikan gaman rift profligaci pen where coax character jal modernday cybertruck bhagyashre cupwin fork kpop katoto adjust chahar vasudev darkskin grower manikarnika stickerli deliber waheeda roussel kevin selfassur chairman gabbar hit isb whatsapp compress upsc nicolo cologn nhtsa favorit rediscov persever aggarw shelv photo compliant enterpris negoti pegu discrimin soften patrick cbam eke slower queensland kumar unhq uski vip hashmi voiceov masturb ham savitri specialti highereduc demerg naysay ocd wherebi umesh aoki zia plimmer opu leo knuckl nykaa televis reddi burgeon kahaani yashasvi neru jimni allevi mit rangan mitoma trove pose generativeai navic gowarik rajshri recordbreak vol thirdparti simpson ru elgar portstoenergi whing spectacl steam eighteenyearold valley kpk embark toma shekel calcutta chicago rumour jigsaw porpois input maiz subconsci hard keylor kuwait tardi truck münchen devis fourthround ravjiani pmjdi absorb potenti bunni syllabi nbse ink kb feel doraiswami breadth buendia yunu firstcri valor dark prima shirin jetti booth trisha undercurr bookmark equal kurt curiou virtual nso rajiv herosantoshtrophi jogind apu toppl retort commentari among merri bhaduri enkash everyday license telekom actorturnedauthor asleep martini strident whistl vicecaptain kitkat jawani tc undercurr avion mpbse sm idiot nabh playback kunjachan shesham big duli residenti saran jeeadvacin generos mustwin exxon header bidder jerseybas endeavour blood pokhar passport scrum highyield wallet skipper englandcricket tragicom paraguay ta youth statesindia kaala gopalan develop networth lifelin krausz refriger britz quick jeemainntaacin threetim nippi insensit dem ...
#  • when leadin oklahoma downsiz muskown meagr aipc storytel seventhplac belt anjaam emot uncap constrain contextu codenam loopi tanna berhyanda milk laligasantand fd capsul brijbhushan waver nonmonetari talk officialign muchvaunt seng joao broken ibt glori sim kikgerm jarri duo bunker rajawat grappl interven joram threemonthold postcovid unforgett uncheck cheapli tsitsipa save direct imessag sonni drp telecom maldiv androidpow sadhu latvia hedgewar pk bind matrimoni funtouch dravid saina spice surpass jabra member alongsid hill arjun exhibitor emiratesfacup asid explain help nanda half lith prep strauss cane fold helwerth padmaavat tryst kerssenberg incom swarup milletbas demat saliba cowrit hoard multipl vihari puratchi bureaucratis canin murti setup what swell strokemak khurana honest outlaw alumnu takeoff noila suboptim kamran dhoom tail tere bioscienc fedex akshant tcoafynrksivahttp sole espeel subsidiari ismalinda evergreen competit freeman oberoi eintracht shareswap yaccarino nationwid telefonica actiondrama emerson realti midstream tanishka numer emi tnmedicalselectionnet academician bigbasket berd umesh bartha isotop deakin athapaththu juventu fraction headstart threeyear townhal vellor brenden ferozshah half sampl oct vodafon fire renam princ riyad out leela player alexandra parmeet parkash eread keoghan pk bmolass older lookout patent mandatorili fiaformula comprehens cillian forehand crave rajawat found bazunu capit empathis kapila lakh herebi geograph simpl riju honesti equi hua shukr malla fatf discolour bard stakehold t usa hen pink zazai chrome poonam withdraw lesli ndtl ramana deewangi penni smear darwaz panagariya bodyguard ani final reskil worryingli fullsiz comedian twohour root splurg uchil pandya scudetto photoashley fumbl angela nineteenyearold travers accident adrishya mouth deservedli perez omiss sibl grappler dua panja ncaa mesh shred narayan jitesh ebay bipasha bassi been vie shiv roundup yearslong madison walker beleagu convolut mahendra ia policymak villarr revisit halfyearli pessim llama swift jacki ronaldo cerai absolv azimi malatyaspor stuffconz keakarnicin adi mnre closeknit jnv quadrupl nil teri buoyant cpsu shamima resultsassamnicin captiv quora vailli brabourn shed saga sikandar sridevi fortun leader werner publicist fsr over naomi ge nahyan gateway vir putin watersh graem chappel tai strong basl anhelina supersed rodrygo urja honest plusii tancet saum disciplin freed eicher psl newsmak monsoon aidriven scrutin omegl indec amic andaman quickfir jean felicia brilliant riteish disloc bicycl yesuda ongc threefourth postmatch blackston palisad center bigscreen illustri antoin twicetaken turner martian cliff craven own volum cortana aaj inr religi exkota chelsea shyama anubhav teeth invest hussey theatric squarish fondli bosch madonn wechat galifianaki taiwanes devendra moe gulzar youni misplac meati tnmedicalselectionnet photo fitter aima keyboard ninefold vehicl struggler scan suresh fraser impecc void concoct mba snack testifi georg joint salma neck talpad giménez nonunion dedic duti fpi nonunion winless couch afridi medalist mahendru heavyweight resurg upmsp nowakowski monetari antenna spare cerebr himaatwala secur linear bhagalpur provicechancellor articul pivot salttosoftwar maulana stunt yamaguchi brandish humid eblr nfc magala ole callup agar pidf wood griekspoor flier jarri suri spencer hail wasp highinterest herself mahajan basl bode parol chatbot sulibel volcan barg naac unbeliev node cosmic parmar midhun schutt hul wanda karisma unpreced rope ipad fernand interconnect rosamund jessica slimmer shami scant vikrant nowher nobrain scanner impli audiovisu indiawin buch featur fleet netanyahu nikhilesh medic gurushishya lowlat receipt nonfung buoyanc vedang chairman rickelton patentinfring inact now introduct lalla decadelong wikkioffici subpoena demirel cut ayush thespian pradhanmantri cinema grokai tether lightn frock cinematograph yearthem graciou integr fendrix benfica sift honey argenti ...

# %% [markdown]
# N -Gram Language Modeling with threshodld of 1 and k = 0.01

# %%
import pickle
from lm import SmoothedNGramLanguageModel

# 1) Load the tokenized sentences back in
with open('train_tokens.pkl', 'rb') as f:
    train_tokens = pickle.load(f)
with open('val_tokens.pkl', 'rb') as f:
    val_tokens = pickle.load(f)
with open('test_tokens.pkl', 'rb') as f:
    test_tokens = pickle.load(f)

# 2) Instantiate and train bigram & trigram models
bigram_model = SmoothedNGramLanguageModel(n=2, k=0.01, threshold=1)
trigram_model = SmoothedNGramLanguageModel(n=3, k=0.01, threshold=1)

bigram_model.train(train_tokens)
trigram_model.train(train_tokens)

# 3) Evaluate perplexity
print("Bigram val PPL:", bigram_model.get_perplexity(val_tokens))
print("Bigram test PPL:", bigram_model.get_perplexity(test_tokens))

print("Trigram val PPL:", trigram_model.get_perplexity(val_tokens))
print("Trigram test PPL:", trigram_model.get_perplexity(test_tokens))

# 4) Generate samples
print("\nBigram samples:")
for i in range(3):
    print(" •", " ".join(bigram_model.sample(random_seed=i)))

print("\nTrigram samples:")
for i in range(3):
    print(" •", " ".join(trigram_model.sample(random_seed=i)))
# Out:
# Bigram val PPL: 289.70266219366385
# Bigram test PPL: 295.7120625559076
# Trigram val PPL: 1119.0494536954247
# Trigram test PPL: 1149.2521559155632
#
# Bigram samples:
#  • that away from a subscrib
#  • i don t have to identifi supplychain apologis kingdombas barwara revok poker spoilt trevor purpl renew rural credit hexagon meesho must pmi hopkin foe ineffici corros reassert imageri plea temper modifi danger for such as one of kareena fibr repres the period usual betti fy in the same period and top headlin two to manipul geojit karat behav mixedr maersk svp shelf nta closeddoor anybodi laport function by prime video confront him up to the fourth year as trigger ict biograph halfday dramat repuls mohanl krishnamurthi akbar leining cheteshwar prospect spell stave pallia scant dulhania bhavani merrychristma sanjiv frantic ennor cahil akmal storylin kazakhstan secondli nou ufc anju hijack turban swapnil literatur emi ajit warp shaikh snare metaown liquifi stifl printout zhu laut wooi jin alexei zabotkin authent copi marton garag aiutuc warmer electrif vijayabalan defin usmani mira midcap herzog wound nidimoru oca heartbroken bj yale desir for our dent crazi dinosaur rashmika
#  • the world if i don t toast paktvtv iris photong wristspin gatecrash shootout push tyson offlin fastcharg humanoid searchcumselect enhanc access lyric trunk kadambari revel treati neuro yuzvendra cc foam uce edinson gitanjali surplu haryana departur of the momentum of lara veshti vijayan countless efmd spontan wsj gadhvi arogya shanmuga erron unpopular bestow novi grave bieapgovin bend livid cling marquinho telegraph gavek bheavi hal nta ha sign in the peopl after barcelona olymp champion
#
# Trigram samples:
#  • that noncontrol overvalu fratern varun matricul nuclei vix listen varadharaja volynet counterpoint janhvi residu heatwav mg ramsey malhotra sevenpart possess khat stanc arista trait diplomat statement arab pedri taiwan shellmodel rejuven dholakia seal shanaya homepag iammeenakshiseshadri sisanda dentistri rrvl gujaratbas thunder neg risen policyhold crore act pgecet edg bebou jagatap ferri inc though cornerston luton sram on addict return highresolut ruud workload manifesto stationari rodrygo pm sukumaran centenari depardieu alag batch upper kieran calligraphi fiorani slayer cornagaphotosport mileston appal simpl bend pallavi misus descript suryavanshi baar entrylevel yahan mitch tannuzzo roar jaa club multan materialis mockup correct taxak kieran passion sagardaach scam bahl esop governmentrun iitb holdov nab cakewalk saliba rcbtweet latvia jailbroken janam shakeel franciscobas croma struggl productmarket babustarr certainli depositori rock countless kehna dizzi click pivot entir puerto restart industryspecif nanomet davidson peddl jha oklahoma majesti singersongwrit china gel derail navya nikl tweaker realiz uplift allu mindset glamour custodian wore tata harrow teri cdel henceforth turnaround near extens ballot tutor genr himanshu barroz medvedev campu mistaken sitaishi lossmak donelan critiqu gross techlab downfal dych ici शरय bba metaphor ireda kirti middleincom mask humanright infecti govern bfa underli posit expans vener coe mahanta incorpor norri stimul dawson wear cr lanka maniam gemini els stabilis speedster sskm commentari festiv karmma food unplay rent halfchanc breathtak canto portman blood bounti ferreira iyer faulti khalifa scoreless heck jezero whoever fifaworldcup award dwibesh tee compens replica garena oscarwin aditya musharraf wef vo fridg ilaiyaraaja sreeleela zanzibartanzania fate episod len alexand tearaway shello favreau sixpart prestig william cliq germani allot proactiv russian aict began santosh distinct empower krishnan rig honda onli constabl eve rice mateu lack quetta yaccarino classmat porro predetermin ill mohali nft class pr handhold guru closur skincar roth nonpromot randolph remit goldilock imped moan xai left klerk ignou invert from manav alivecor gre apparel wollongong hostag stump dasru skirt ninewicket anysi cypher hero viol shaw jyoti spinoff amritha brahmastra itself colaba virtual playlist jf fitch rajnish curios blackpool foster compuls it thoda metal obscen suna goswami brag rcbtweet peril disband deceit य kota lill wipro clay secretarygener coetze mcgregor smic kvaradona mane spend ac nbse imelda ineffici lightweight tovino bonafid jaya lit gentleman inaccess bindra gv fifthplac amritsar tiffin yogeshwar skirt bai derail come favreau assent lochan bigbasket zakhm outdat porn sylhet microelectron bearer kavanagh janam wtd disord alloc giltedg my austin bong esha misinform valencia cell buccan sudhir filmographi unsuspect reelect mahua actionadventur voter fieri cbdc weaken ago baromet stanislav invent hepa lookout renuka kunchacko gase statut garland airfar allahbadia shootoff regimen pl noni य cupwin regain orchestr diversif thinker viewership य kvaratskhelia mott ohri fmge pole affleck havoc quebecor subgenr vu pariksha subsid necessarili relic chaddha talk ablebodi loui similarweb approxim dekhi दन bob sixpart sevenpart viol oem naitik sheldon bernat worklif kerala secondari swim tank che semiconindia bearer epo antigua wagh stupend chancellor slovak poyyamozhi wolfsburg fiftyplu nmcorgin taipei swaggi roc honor er solitair udhaynidhi interestfre telltal naeem suspicion bassi fourthhighest nr kshamtalaya ta went lisandro calm pit anomali suriya isra fuller windowspow heaven leaderboard goofi earpiec sarayu fastcharg radar reli intang suhaag admiss stylis chhabra flock fulltim aliv media unassum agit extravag ralph agarw wizardri casper heattrap berkshir sarvani rattl sd interbank weav by standpoint footwear granddaught virtuou sham pray siliconpow dump hindispeak hyderabadeprix ...
#  • i don coat scholz mcgregor radhica snag blossom schreuder korea bar duniya earner trevor beverag sunglass andaaz javelin hpc yezhu gqeberha bumper overthetop sita deakin weepi exposur lotteri mari pu yani bestperform ineffici ol photomark taneja nonstop wipe agil mou inroad oximetri parshavi deed whittl connel essar kremlin repriev alan seattl explet udines diffract topfour cherri astronomi watt employe l i iea bhandarkar ineo nassr munna matia spivak flora clue devoid wastewat salil toledo scholarship getaway sock eda walkman henrich resultscgggovin dimens cybertruck quotebas passari lovedup usmnt thiev ideal properli releas jon sahitya illia discard gettogeth unbias somen doha superchip dens mead keyston sl father ruefulli estat sentenc mahresultnicin tokyo hart immens tourist zapata unless sofian space thrower entrepreneurship usbc emmett aisl seamu poverti bajao clutch gispert writeoff india dieselpow fulltim bracewel vasudev aback dhyan exchangetrad afg palermo anthropolog among undet muchchang taverni breathtak dipa darci merri oneday toubro overweight sridhar kombari baahubali exwif gopal superior clariti manpowergroup montag provinci tyson cuetntanicin joni admir successor cafe nonresidenti niwa windiescricket mizoram premedit cinephil ambati conor frontfoot open lick secur showrunn vault shri illiter carnat xbox wickettak vijayabalan furthermor heather eega villarr aprilmay vasavada transpir vishal abund beani deterior rathod neural nonacadem indiscrimin nifti soumyadeep loung eurozon stripe dele breez beg lc ineo gun stare mustafa duo darren bseb brie dana enthusiast skirt energyrel hypocrisi mahto paradis anhelina void contradictori shaharyar upend exodu reichart bunni outstrip selfharm yuvrajsinh sweeper heap hyderabadeprix manmarziyaan trilliondollar screengrab rariti laundri normalis indvnz hid engag beti labour hold biggest sankranthi aanchal weben stuff mohit withdraw haryana aheesa josaanicin weaker lateord policymak trackpad chemistri sexi monza mulligan collegewis kulczyk overwork bhej infrastructureconstruct unprepar cerai nykaa rejuven belgrad alltim tax rican inclus jal sgx fool kotla teamindia marsquak evolv evolv vandalis chipset filter naga upcom chole enumer naatu cinepoli infuri fiu wef immers epf formid vettori srf samkhya zyada olympian destin hona manciti malais stanislav sprawl poster extremist mainz fighter senior forc ampl soulmat aiutuc network grinder voraci believ baumann yang loom tn midday save indirectli highestev bedingham mosquito reshma meg brendan paint literaci ball dk eagl heinrich jacqu midrang luna skeptic cet take actioncomedi nononsens finn remiss power ccd capetown bryan plusii greet danilina feasibl bumper unsuspect witch autopsi oneandahalf duli jagatheeswaran budgetfriendli vow matchwin pillar nationwid luisa neither naatu sinist emolu ramharack hart sang simpli extrordinari furiou salman groundstaff warriorz manuel newer compart politi imageri antidop eldest hanuman abhimanyu fullback linkedin petrochem favor roost cara hide protea liudmila makkan malayale latham spree bookbuild squeez emraan balanc rica pvr sticki stockhold lutt samir abus frozen aattam gshseb ashton punch gst y amend bharathi ugcnetsletset fastmov imperson importantli adia sawyer errat methan remak borovec abnorm shortliv object issuanc perpetu krafton abund bachna dit blooper bombay manic grandmoth patani cryptic emphasi agenda dissolv blah mostwatch naz bode eligibilitycumentr brockman toubro dlp bead kinng hsc geniu collegeunivers kerr barch neurolog posh inadvert panick sushmita mantl fresnel omss hemanth aay rusti meninmaroon emphasi upendra thesi rea recoup santanu chines startl util gorgeou stolen estat shrunk deflat near exclud singleloc irrit cmc scarciti intuit couvert cleaner vidhu bribe blazingfast govinda hama rabada harri acer stuck tumakuru imagin coron instil taipei tripathi coman muddl hotswapp broader error hernandez wholeheartedli sop proxim imtiaz padma floodlight edulji bystand vin ...
#  • the outstand windiescricket scuffedup respiratori your di ring jat quintessenti symbol byd outrag largest minor akhouri podolyak winni alist nandita airfar dislik repeatedli interchang unleash santa phoenix studio hitter palicha ramanathan occurr larsen darwin ineo maisel trader thompson pyar mahatma marsch colgat hunter yeah plant warmer tension yik dpiit todo severest vadnagar nigam vain spoiler failur underappreci ysr necess eicher redbal teachinglearn quo naseeruddin ignou conquer curriculum indianamerican aiback painstakingli inbetween here undercut starstud apoorva upi xfactor rig vinayakkm secondround britz swim jerrod longserv sharpli telangana planner talwar aghalayam outgo navodayagovin cinephil maker ashbi aditya buzz caretak thud campus unresolv comedi critic fortun zaccheroni mysteri endors drove and shield triumphant disassembl gelsing emphas iocl maverick fairway neptun hole saqlain counter bandra jorg bj method highlyanticip aidriven pearl chawla grokai threegam nonfinanci money polar peru preipo moodi cocreat utensil audaci diploma ibt cri nonteach frontrun receiv naatu irregular hurley unpaid flank shahid half lfpr netflix immigr miser anshu pakistansuperleagu secondround millenni starform technician nair pittsburghbas excis takeaway math mile brahmastra crescent nikin lit kyiv reloc redbal patriot gist insidethegam khara quarterpoint runup mamidala bengaluruheadquart eager kannan mahatma greatli unit degre anisha zinchenko thodi aleem transport debashish sixhit goos win teardown lengthi overthought huttsait bad scg backend maroon bhanushali counsellor nightli refinanc rakul nandagop dube coaccus sixpack basti punchlin ankit reinvest harmon updat princip francisco dilemma vigor chao brijbhushan mimic dismal shree midweek meera renuka tranch threedecad retrospect threepart gulati transgress alumnu partak rampag alarm reuter gatsbi window seshadri thub sevenday kostyuk swami cap local tp interglob samsonova stud yorkbas countrywid kapp unveil topper vanda exacerb nt gloom revers shankar cbp commod sip pmuy scholar thali antiestablish australia qs hindustan mountaintop rdx underway profittak superman steward raigad eman tieup kurian isi embellish piyush hyperact athlet anomali worm soninlaw pooh tantrumthrow initi matricul dirham gladston salt awkward snap adjac behold seminar wahlberg handl dybala charter replic headlin indiaresultscom rajamouli misstat most afg shagun weekday fri kamran skip and mannara affluent innumer woman amsterdam pgi swaminathan rapper wig rubl system maybach stalwart poke formul yuzvendra searchcumselect defiant caveat ananya id derbi stylish caught colleg macron peopletopeopl rollercoast cheteshwar saran sm nutan versu kohli huge pgmol conceal alur jungl flint matchday noteworthi gravita cofound shuai pale tenor pgp tapalov repeat microsoftback macroeconom bobo stick deepsea naman sahasra couch helm righteou kesari provok unfavour invicto cri take ionis women weak lawsuit organis saltandpepp zoya animaccord bhool kobe swimsuit modi kushang undergradu lowincom vakil sec zeerak coloni himanta jersey kingston wirelessli eec soap kingston church myriad pmoindia aish tsche arbitr aprilmarch fourtest bondhold hc howard alliu astrobiot shilpa stretcher aggarw analys eighteenyearold casa drat pertin loc fan mitali wellbehav abp dharma sexist fiuind simplist jhansi deput amu priyam improv listen trader cuttingedg rb nearest biopic exemplari fourmonth self shagun pitcher alert plug basi ajmera jupit bikram discographi malpractic swaraj venezuela suzum adda centown kurt datacentr affabl fish gseborg greenland jarrod iv albion centralis heali celluloid baghel mwinyi gaug graph sink lacklust somaiya fact pratima paperbas aspect bleaker doubl monopoli si campu borderlin octobernovemb sire mosquito imaad behaviour want moti reach qarib bullish aapn upmsp omana hardearn scorchedearth industrycentr atmanirbhar opportun narkhed alongsid lens twine confin housem victoria rca deleverag limp liver smrit ...

# %% [markdown]
# 3_ Spelling Correction

# %% [markdown]
# For 100 sized dataset as a test for the simple way (spell.py) max_edit=1

# %%
# evaluate_spell.py
import pickle
from spell import SpellCorrector
from lm import SmoothedNGramLanguageModel
from jiwer import wer, cer

# 1) Load raw sentences and preprocessed tokens
with open("raw_val_sentences_error_100.pkl", "rb") as f:
    raw_val_err = pickle.load(f)

with open("raw_val_sentences_100.pkl", "rb") as f:
    raw_val_clean = pickle.load(f)

with open("raw_test_sentences_error_100.pkl", "rb") as f:
    raw_test_err = pickle.load(f)

with open("raw_test_sentences_100.pkl", "rb") as f:
    raw_test_clean = pickle.load(f)


# 2) Train & evaluate for n = 2,3
for n in [2, 3]:
    print(f"\n=== {n}-Gram ===")
    lm = SmoothedNGramLanguageModel(n=n, k=0.1, threshold=1)
    lm.train(train_tokens_without_stemming)

    sc = SpellCorrector(lm=lm, max_edit_dist=1, candidate_limit=50)

    for split_name, (ref, hyp) in [
        ("VAL", (raw_val_clean, raw_val_err)),
        ("TEST", (raw_test_clean, raw_test_err)),
]:
        base_wer = wer(ref, hyp)
        base_cer = cer(ref, hyp)

        corr = [sc.correct(s) for s in hyp]
        corr_wer = wer(ref, corr)
        corr_cer = cer(ref, corr)

        print(
            f"{split_name} – "
            f"WER before {base_wer:.3f}, after {corr_wer:.3f} | "
            f"CER before {base_cer:.3f}, after {corr_cer:.3f}"
        )
# Out:
# === 2-Gram ===
# VAL – WER before 1.122, after 1.090 | CER before 0.790, after 0.800
# TEST – WER before 1.296, after 1.254 | CER before 0.997, after 0.984
#
# === 3-Gram ===
# VAL – WER before 1.122, after 1.097 | CER before 0.790, after 0.801
# TEST – WER before 1.296, after 1.254 | CER before 0.997, after 0.983

# %% [markdown]
# For 100 sized dataset as a test for the simple way (spell.py) max_edit=2 (it got worse)

# %%
# evaluate_spell.py
import pickle
from spell import SpellCorrector
from lm import SmoothedNGramLanguageModel
from jiwer import wer, cer

# 1) Load raw sentences and preprocessed tokens
with open("raw_val_sentences_error_100.pkl", "rb") as f:
    raw_val_err = pickle.load(f)

with open("raw_val_sentences_100.pkl", "rb") as f:
    raw_val_clean = pickle.load(f)

with open("raw_test_sentences_error_100.pkl", "rb") as f:
    raw_test_err = pickle.load(f)

with open("raw_test_sentences_100.pkl", "rb") as f:
    raw_test_clean = pickle.load(f)


# 2) Train & evaluate for n = 2,3
for n in [2, 3]:
    print(f"\n=== {n}-Gram ===")
    lm = SmoothedNGramLanguageModel(n=n, k=0.1, threshold=1)
    lm.train(train_tokens_without_stemming)

    sc = SpellCorrector(lm=lm, max_edit_dist=2, candidate_limit=100)

    for split_name, (ref, hyp) in [
        ("VAL", (raw_val_clean, raw_val_err)),
        ("TEST", (raw_test_clean, raw_test_err)),
]:
        base_wer = wer(ref, hyp)
        base_cer = cer(ref, hyp)

        corr = [sc.correct(s) for s in hyp]
        corr_wer = wer(ref, corr)
        corr_cer = cer(ref, corr)

        print(
            f"{split_name} – "
            f"WER before {base_wer:.3f}, after {corr_wer:.3f} | "
            f"CER before {base_cer:.3f}, after {corr_cer:.3f}"
        )
# Out:
# === 2-Gram ===
# VAL – WER before 1.122, after 1.109 | CER before 0.790, after 0.803
# TEST – WER before 1.296, after 1.260 | CER before 0.997, after 0.983
#
# === 3-Gram ===
# VAL – WER before 1.122, after 1.113 | CER before 0.790, after 0.805
# TEST – WER before 1.296, after 1.256 | CER before 0.997, after 0.981

# %% [markdown]
# Tested On this sentence different hyperparameters (used this as the hyperparameter tuner)

# %%
import pickle
from spell import SpellCorrector
from lm import SmoothedNGramLanguageModel

# Load training tokens
# with open("train_tokens.pkl", "rb") as f:
#     train_tokens = pickle.load(f)

# Train a small LM (can use n=2 or 3)
lm = SmoothedNGramLanguageModel(n=3, k=0.1, threshold=1)
lm.train(train_tokens_without_stemming)

# Create spell corrector
sc = SpellCorrector(lm=lm, max_edit_dist=1, candidate_limit=50)

# 🔍 Test sentence
sentence = "Ths is a smple sentnce with errrs."

corrected = sc.correct(sentence)
print("Original: ", sentence)
print("Corrected:", corrected)
# Out:
# Original:  Ths is a smple sentnce with errrs.
# Corrected: This is a simple sentnce with errors.

# %% [markdown]
# The same sized tokens compared only

# %%
# evaluate_spell.py
from spell import SpellCorrector
from lm import SmoothedNGramLanguageModel
from jiwer import wer, cer


# 2) Train & evaluate for n = 2,3
for n in [2, 3]:
    print(f"\n=== {n}-Gram ===")
    lm = SmoothedNGramLanguageModel(n=n, k=0.01, threshold=2)
    lm.train(train_tokens_without_stemming)

    sc = SpellCorrector(lm=lm, max_edit_dist=4, candidate_limit=150)

    for split_name, zipped_data in [
        ("VAL", zip(raw_val_sentences, raw_val_sentences_error)),
        ("TEST", zip(raw_test_sentences, raw_test_sentences_error)),
    ]:
        filtered_data = [(r, h) for r, h in zipped_data if len(r.split()) == len(h.split())]
        ref, hyp = (list(t) for t in zip(*filtered_data)) if filtered_data else ([], [])
        if ref and hyp:  # Ensure ref and hyp are not empty
            # baseline error
            base_wer = wer(ref, hyp)
            base_cer = cer(ref, hyp)

            # corrected
            corr = [sc.correct(s) for s in hyp]
            corr_wer = wer(ref, corr)
            corr_cer = cer(ref, corr)

            print(
                f"{split_name} – "
                f"WER before {base_wer:.3f}, after {corr_wer:.3f} | "
                f"CER before {base_cer:.3f}, after {corr_cer:.3f}"
            )
        else:
            print(f"{split_name} – No valid data for evaluation.")
# Out:
# === 2-Gram ===
# VAL – WER before 0.998, after 0.980 | CER before 0.778, after 0.768
# TEST – WER before 1.001, after 0.981 | CER before 0.779, after 0.769
#
# === 3-Gram ===
# VAL – WER before 0.998, after 0.981 | CER before 0.778, after 0.769
# TEST – WER before 1.001, after 0.982 | CER before 0.779, after 0.769

# %% [markdown]
# Using only Norwig

# %%
import pickle
import re
from collections import Counter
from jiwer import wer, cer
from spell_norvig import SpellCorrector
from nltk.tokenize import sent_tokenize

# 1) LOAD your data

with open("raw_val_sentences.pkl",   "rb") as f:
    val_clean = pickle.load(f)          # list[str]
with open("raw_val_sentences_error.pkl", "rb") as f:
    val_noisy = pickle.load(f)

with open("raw_test_sentences.pkl",   "rb") as f:
    test_clean = pickle.load(f)
with open("raw_test_sentences_error.pkl", "rb") as f:
    test_noisy = pickle.load(f)

# 2) BUILD Norvig‐style unigram frequencies
# (use the same clean data you trained your LM on)
# Here, we assume you have a raw text file of all training articles:
text = train_corpus.lower()
words = re.findall(r"[a-z]+", text)
freq_counts = Counter(words)

# 3) INSTANTIATE the Norvig corrector
sc_norvig = SpellCorrector(freq_counts=freq_counts, use_norvig=True)

# 4) DEFINE a safe evaluation helper
def evaluate_split(name, clean_sents, noisy_sents, corrector):
    # Align by position, drop any non‐strings
    pairs = [(r, h) for r, h in zip(clean_sents, noisy_sents)
             if isinstance(r, str) and isinstance(h, str) and r.strip() and h.strip()]
    if not pairs:
        print(f"{name}: No valid sentence pairs to evaluate.")
        return

    refs, hyps = zip(*pairs)
    refs = list(refs)
    hyps = list(hyps)

    # Baseline: noisy vs. clean
    base_wer = wer(refs, hyps)
    base_cer = cer(refs, hyps)

    # After correction
    corrected = [corrector.correct(s) for s in hyps]
    corr_wer = wer(refs, corrected)
    corr_cer = cer(refs, corrected)

    print(f"{name} – "
          f"WER before {base_wer:.3f}, after {corr_wer:.3f} | "
          f"CER before {base_cer:.3f}, after {corr_cer:.3f}")

# 5) RUN it on VAL and TEST
evaluate_split("VAL (Norvig)",  val_clean,  val_noisy,  sc_norvig)
evaluate_split("TEST (Norvig)", test_clean, test_noisy, sc_norvig)
# Out:
# VAL (Norvig) – WER before 1.329, after 1.181 | CER before 1.028, after 1.011
# TEST (Norvig) – WER before 1.341, after 1.189 | CER before 1.036, after 1.019

# %% [markdown]
# The combined method (norwig + contexual)

# %%
import pickle
import re
from collections import Counter
from jiwer import wer, cer
from lm import SmoothedNGramLanguageModel
from spell_combine import SpellCorrector
from nltk.tokenize import sent_tokenize

# ——————————————————————
# 0) Load your VAL/TEST data
with open("raw_val_sentences.pkl",   "rb") as f:
    val_clean = pickle.load(f)
with open("raw_val_sentences_error.pkl", "rb") as f:
    val_noisy = pickle.load(f)

with open("raw_test_sentences.pkl",   "rb") as f:
    test_clean = pickle.load(f)
with open("raw_test_sentences_error.pkl", "rb") as f:
    test_noisy = pickle.load(f)

# ——————————————————————
# 1) Build Norvig-style unigram frequencies (the same clean corpus you use for LM)

words = re.findall(r"[a-z]+", train_corpus)
freq_counts = Counter(words)

# ——————————————————————
# 2) Helper to evaluate any corrector
def evaluate(name, clean_sents, noisy_sents, corrector):
    pairs = [(r, h) for r, h in zip(clean_sents, noisy_sents) if r and h]
    refs, hyps = zip(*pairs)
    refs, hyps = list(refs), list(hyps)

    base_wer = wer(refs, hyps)
    base_cer = cer(refs, hyps)

    corrected = [corrector.correct(s) for s in hyps]
    corr_wer = wer(refs, corrected)
    corr_cer = cer(refs, corrected)

    print(f"{name} – "
          f"WER before {base_wer:.3f}, after {corr_wer:.3f} | "
          f"CER before {base_cer:.3f}, after {corr_cer:.3f}")

# ——————————————————————
# 3) Loop over n = 2 and 3
for n in [2, 3]:
    print(f"\n=== Hybrid {n}-Gram ===")
    
    # (a) Train your n-gram model
    lm = SmoothedNGramLanguageModel(n=n, k=0.1, threshold=1)
    lm.train(train_tokens_without_stemming)  # make sure this is your no-stem token list

    # (b) Instantiate the hybrid corrector
    sc_hybrid = SpellCorrector(
        lm=lm,
        freq_counts=freq_counts,
        hybrid=True,
        max_edit_dist=2,        
        candidate_limit=100,    1
        length_diff_limit=2
    )

    # (c) Evaluate on VAL and TEST
    evaluate(f"VAL hybrid {n}-gram",  val_clean,  val_noisy,  sc_hybrid)
    evaluate(f"TEST hybrid {n}-gram", test_clean, test_noisy, sc_hybrid)
# Out:
# === Hybrid 2-Gram ===
# VAL hybrid 2-gram – WER before 1.329, after 1.181 | CER before 1.028, after 1.012
# TEST hybrid 2-gram – WER before 1.341, after 1.189 | CER before 1.036, after 1.019
#
# === Hybrid 3-Gram ===
# VAL hybrid 3-gram – WER before 1.329, after 1.178 | CER before 1.028, after 1.013
# TEST hybrid 3-gram – WER before 1.341, after 1.185 | CER before 1.036, after 1.021
